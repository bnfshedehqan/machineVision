# %%
# !pip install -q mediapipe
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 24.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 1.4 MB/s eta 0:00:00

# %%
import mediapipe as mp

print(mp.__version__)
# Out:
# 1.0.1

# %%
import mediapipe as mp

from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# %%
# !wget -q https://storage.googleapis.com/mediapipe-models/hand_landmarker/hand_landmarker/float16/1/hand_landmarker.task

# %%
base_options = python.BaseOptions(
    model_asset_path="hand_landmarker.task"
)

options = vision.HandLandmarkerOptions(
    base_options=base_options,
    num_hands=2
)

detector = vision.HandLandmarker.create_from_options(
    options
)

# %%
image = mp.Image.create_from_file("hand.jpg")

result = detector.detect(image)

# %%
print(result)
# Out:
# HandLandmarkerResult(handedness=[[Category(index=0, score=0.9985284209251404, display_name='Right', category_name='Right')], [Category(index=1, score=0.7458421587944031, display_name='Left', category_name='Left')]], hand_landmarks=[[NormalizedLandmark(x=0.7018930912017822, y=0.5362659096717834, z=-2.2493233586828865e-07, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.6950150728225708, y=0.4265671670436859, z=-0.10145238786935806, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.7754249572753906, y=0.3185914158821106, z=-0.10884010046720505, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.8343315720558167, y=0.23412680625915527, z=-0.08585835993289948, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.8740809559822083, y=0.16984456777572632, z=-0.05765201151371002, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.9189891219139099, y=0.3621335029602051, z=-0.05626406893134117, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.9564719200134277, y=0.2307235598564148, z=-0.02808929979801178, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.9463695287704468, y=0.1523909568786621, z=-0.014249179512262344, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.9350609183311462, y=0.0969262421131134, z=-0.0058727082796394825, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.9337679147720337, y=0.3890123665332794, z=0.01852445676922798, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.9463798999786377, y=0.2538629174232483, z=0.05795334279537201, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.9347492456436157, y=0.16486865282058716, z=0.06168626621365547, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.9094633460044861, y=0.10136809945106506, z=0.057832732796669006, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.9214617609977722, y=0.4003066420555115, z=0.0893535241484642, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.9151649475097656, y=0.2800455093383789, z=0.11956559866666794, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.9048560857772827, y=0.20063377916812897, z=0.10506980866193771, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.8939208388328552, y=0.14367824792861938, z=0.08920491486787796, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.9044918417930603, y=0.4026696979999542, z=0.15364517271518707, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.8981024026870728, y=0.3097692131996155, z=0.16917458176612854, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.8855604529380798, y=0.25576889514923096, z=0.16341756284236908, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.8745414018630981, y=0.21789464354515076, z=0.1581866294145584, visibility=None, presence=None, name=None)], [NormalizedLandmark(x=0.4414324164390564, y=0.6244415044784546, z=1.6849214716785355e-06, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.37704646587371826, y=0.5710400938987732, z=-0.10762154310941696, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.2859417498111725, y=0.5094985961914062, z=-0.13248984515666962, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.2140258252620697, y=0.44929274916648865, z=-0.13431870937347412, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.1421675831079483, y=0.3981039524078369, z=-0.13036401569843292, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.18057206273078918, y=0.48094746470451355, z=-0.04299234226346016, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.10500968992710114, y=0.3820223808288574, z=-0.045057691633701324, visibility=None, presence=None, name=None), NormalizedLandmark(x=0.06329381465911865, y=0.3140771687030792, z=-0.060974735766649246, ...

# %%
hand_landmarks = result.hand_landmarks

print(len(hand_landmarks))
# Out:
# 2

# %%
for landmark in hand_landmarks[0]:
    print(
        "x =", landmark.x,
        "y =", landmark.y,
        "z =", landmark.z
    )
# Out:
# x = 0.7018930912017822 y = 0.5362659096717834 z = -2.2493233586828865e-07
# x = 0.6950150728225708 y = 0.4265671670436859 z = -0.10145238786935806
# x = 0.7754249572753906 y = 0.3185914158821106 z = -0.10884010046720505
# x = 0.8343315720558167 y = 0.23412680625915527 z = -0.08585835993289948
# x = 0.8740809559822083 y = 0.16984456777572632 z = -0.05765201151371002
# x = 0.9189891219139099 y = 0.3621335029602051 z = -0.05626406893134117
# x = 0.9564719200134277 y = 0.2307235598564148 z = -0.02808929979801178
# x = 0.9463695287704468 y = 0.1523909568786621 z = -0.014249179512262344
# x = 0.9350609183311462 y = 0.0969262421131134 z = -0.0058727082796394825
# x = 0.9337679147720337 y = 0.3890123665332794 z = 0.01852445676922798
# x = 0.9463798999786377 y = 0.2538629174232483 z = 0.05795334279537201
# x = 0.9347492456436157 y = 0.16486865282058716 z = 0.06168626621365547
# x = 0.9094633460044861 y = 0.10136809945106506 z = 0.057832732796669006
# x = 0.9214617609977722 y = 0.4003066420555115 z = 0.0893535241484642
# x = 0.9151649475097656 y = 0.2800455093383789 z = 0.11956559866666794
# x = 0.9048560857772827 y = 0.20063377916812897 z = 0.10506980866193771
# x = 0.8939208388328552 y = 0.14367824792861938 z = 0.08920491486787796
# x = 0.9044918417930603 y = 0.4026696979999542 z = 0.15364517271518707
# x = 0.8981024026870728 y = 0.3097692131996155 z = 0.16917458176612854
# x = 0.8855604529380798 y = 0.25576889514923096 z = 0.16341756284236908
# x = 0.8745414018630981 y = 0.21789464354515076 z = 0.1581866294145584

# %%
if result.hand_landmarks:

    landmark = result.hand_landmarks[0][8]

    image_width = image.width
    image_height = image.height

    pixel_x = int(
        landmark.x * image_width
    )

    pixel_y = int(
        landmark.y * image_height
    )

    print("\nLandmark 8:")
    print("Normalized:",
          landmark.x,
          landmark.y)

    print("Pixel:",
          pixel_x,
          pixel_y)
# Out:
# Landmark 8:
# Normalized: 0.9350609183311462 0.0969262421131134
# Pixel: 1145 134
